# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
#from config import g_key
import sys
sys.path.append("C:/Users/laura/bootcamp/")
from api_keys import g_key

# %%
#read csv from weather data api
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City ID             City Country                 Date      Lat       Lng  \
# 0        0         Qaqortoq      GL  2021-12-20 22:01:55  60.7167  -46.0333
# 1        1  Lazaro Cardenas      MX  2021-12-20 22:01:56  17.9583 -102.2000
# 2        2             Dale      US  2021-12-20 22:01:57  38.1689  -86.9900
# 3        3  Nizhnyaya Poyma      RU  2021-12-20 22:01:57  56.1622   97.1933
# 4        4           Hobart      AU  2021-12-20 22:00:18 -42.8794  147.3294
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     50.50        72          71       14.12
# 1     83.41        64          25        7.09
# 2     42.58        65           1        3.44
# 3     -9.81        89         100        7.40
# 4     62.46        53          75       13.80

# %%
#city_data_df.dtypes

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)
fig = gmaps.figure()
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# fig2 = gmaps.figure()
# fig2

# %%
# get temperatures that are above 0
max_temp=city_data_df["Max Temp"]
temps=[]
for i in max_temp:
    temps.append(max(i,0))

# %%
# min_temp=0
# new_city_data_df=city_data_df.loc[city_data_df["Max Temp"]>=min_temp]
# new_city_data_df

# %%
# temps_series=pd.Series(temps)
# temps_series

# %%
#max temp heat map
#1. assign the locations to an array of latitiude and longitude pairs
locations=city_data_df[["Lat","Lng"]]
#2. assign the weights variable to some values
max_temp=city_data_df["Max Temp"]
#3. assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#4. assign the heatmap_layer varibale to the heatmap_layer attribute and add in the location
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], 
                                 dissipating=False, max_intensity=300, point_radius=4)

#list comprehension
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp]

#add the heatmap layer
fig.add_layer(heat_layer)
#call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#humidity heat map
#1. assign the locations to an array of latitiude and longitude pairs
locations=city_data_df[["Lat","Lng"]]
#2. assign the weights variable to some values
humidity=city_data_df["Humidity"]
#3. assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#4. assign the heatmap_layer varibale to the heatmap_layer attribute and add in the location
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=300, point_radius=4)

#list comprehension
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp]

#add the heatmap layer
fig.add_layer(heat_layer)
#call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#cloudiness heat maps
#1. assign the locations to an array of latitiude and longitude pairs
locations=city_data_df[["Lat","Lng"]]
#2. assign the weights variable to some values
clouds=city_data_df["Cloudiness"]
#3. assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#4. assign the heatmap_layer varibale to the heatmap_layer attribute and add in the location
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, 
                                 dissipating=False, max_intensity=300, point_radius=4)

#list comprehension
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp]

#add the heatmap layer
fig.add_layer(heat_layer)
#call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#wind speed heat maps
#1. assign the locations to an array of latitiude and longitude pairs
locations=city_data_df[["Lat","Lng"]]
#2. assign the weights variable to some values
wind=city_data_df["Wind Speed"]
#3. assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#4. assign the heatmap_layer varibale to the heatmap_layer attribute and add in the location
heat_layer = gmaps.heatmap_layer(locations, weights=wind, 
                                 dissipating=False, max_intensity=300, point_radius=4)

#list comprehension
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp]

#add the heatmap layer
fig.add_layer(heat_layer)
#call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City ID               City Country                 Date      Lat  \
# 1         1    Lazaro Cardenas      MX  2021-12-20 22:01:56  17.9583
# 7         7              Hobyo      SO  2021-12-20 22:01:59   5.3505
# 18       18  Bahia De Caraquez      EC  2021-12-20 22:02:07  -0.6000
# 21       21         Georgetown      MY  2021-12-20 22:02:08   5.4112
# 26       26             Atuona      PF  2021-12-20 22:02:10  -9.8000
# 32       32     Saint-Philippe      RE  2021-12-20 22:02:13 -21.3585
# 34       34            Kavieng      PG  2021-12-20 22:02:14  -2.5744
# 35       35          Bundaberg      AU  2021-12-20 22:02:15 -24.8500
# 38       38            Rikitea      PF  2021-12-20 22:02:16 -23.1203
# 41       41               Hilo      US  2021-12-20 21:58:31  19.7297
#
#          Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 1  -102.2000     83.41        64          25        7.09
# 7    48.5268     78.24        81          78       17.96
# ...

# %%
preferred_cities_df.count()
# Out:
# City ID       138
# City          138
# Country       137
# Date          138
# Lat           138
# Lng           138
# Max Temp      138
# Humidity      138
# Cloudiness    138
# Wind Speed    138
# dtype: int64

# %%
preferred_cities_df.isnull().sum()
# Out:
# City ID       0
# City          0
# Country       1
# Date          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# dtype: int64

# %%
#temps_series

# %%
# params = {
#     "radius": 5000,
#     "type": "lodging",
#     "key": g_key
# }

# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

#     # Make request and get the JSON data from the search. 
# test = requests.get(base_url, params=params).json()
# test

# %%
preferred_cities_new = preferred_cities_df.dropna()

# %%
preferred_cities_new.count()
# Out:
# City ID       137
# City          137
# Country       137
# Date          137
# Lat           137
# Lng           137
# Max Temp      137
# Humidity      137
# Cloudiness    137
# Wind Speed    137
# dtype: int64

# %%
#create dataframe called hotel_df to store hotel names along with city, country, max temp, and coordinates
hotel_df=preferred_cities_df[["City","Country","Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"]=""
hotel_df.head()
# Out:
#                  City Country  Max Temp      Lat       Lng Hotel Name
# 1     Lazaro Cardenas      MX     83.41  17.9583 -102.2000
# 7               Hobyo      SO     78.24   5.3505   48.5268
# 18  Bahia De Caraquez      EC     75.81  -0.6000  -80.4167
# 21         Georgetown      MY     78.89   5.4112  100.3354
# 26             Atuona      PF     77.94  -9.8000 -139.0333

# %%
#set parameters to search for a hotel
params={"radius":5000, "types": "lodging", "key":g_key}

# %%
#test for Paris
params_Paris={"radius":5000, "types": "lodging", "key":g_key,"location":"48.8566,2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#make request to get JSON from the search
hotels=requests.get(base_url,params=params_Paris).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEDGFI74xye1oa-2he0Y_W36mOv18nPjCugYhct9PtTWlIvwbr3xUrAO35HimRS2bNJ6j7uQMfjmqHxYpCZ5yiGUpQaLONQvQ5bjQjzsVbS6W6UgZLX8k1PSBKt0aHWOnmJq1xs3dQSoGtvILnkGGWP2J-95g0zSb0XTI5Vusu3m1b3aS0-T09igEpi8aWyasHr-I6FfrJ8PJiR9YcUF_m0eZA7zG_eL5XFtWb7MiDMpUTud1sPODMsnimo5r4lqXAp8dRsjAcXY6WbI4KuI7mxECkcYOKt8ZtO9SRalJpMbf2U5rMe6yKDco7SGRAHKBC9GsB_RxnDi5ebfq1_UqhCOQsLfpZhlEf728yaP-Htbg4eaZLMCqbWGnEaT_SfTEWwj9V8krZN-CHYa8vc-X1DOaKM7TgApvUjZFB0OTCg57w89vOkFungn',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
# ...

# %%
import json
print(json.dumps(hotels, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEDGFI74xye1oa-2he0Y_W36mOv18nPjCugYhct9PtTWlIvwbr3xUrAO35HimRS2bNJ6j7uQMfjmqHxYpCZ5yiGUpQaLONQvQ5bjQjzsVbS6W6UgZLX8k1PSBKt0aHWOnmJq1xs3dQSoGtvILnkGGWP2J-95g0zSb0XTI5Vusu3m1b3aS0-T09igEpi8aWyasHr-I6FfrJ8PJiR9YcUF_m0eZA7zG_eL5XFtWb7MiDMpUTud1sPODMsnimo5r4lqXAp8dRsjAcXY6WbI4KuI7mxECkcYOKt8ZtO9SRalJpMbf2U5rMe6yKDco7SGRAHKBC9GsB_RxnDi5ebfq1_UqhCOQsLfpZhlEf728yaP-Htbg4eaZLMCqbWGnEaT_SfTEWwj9V8krZN-CHYa8vc-X1DOaKM7TgApvUjZFB0OTCg57w89vOkFungn",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8581126,
#                     "lng": 2.3529277
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8594360302915,
#                         "lng": 2.354355480291502
#                     },
#                     "southwest": {
# ...

# %%
len(hotels["results"])
# Out:
# 20

# %%
hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'

# %%
#iterate through the dataframe
for i, row in hotel_df.iterrows():
    #get latitude and longitude
    lat=row["Lat"]
    lng=row["Lng"]
    
    #add lat and lng to location keey for the params dictionary
    params["location"]=f"{lat},{lng}"
    
    #use the search term "lodging" and lat and lng
    base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    #make request for json
    hotels=requests.get(base_url,params=params).json()
    #grad first hotel from the results and store the name
    try:
        hotel_df.loc[i, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping")
# Out:
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping

# %%
hotel_df.head()
# Out:
#                  City Country  Max Temp      Lat       Lng  \
# 1     Lazaro Cardenas      MX     83.41  17.9583 -102.2000
# 7               Hobyo      SO     78.24   5.3505   48.5268
# 18  Bahia De Caraquez      EC     75.81  -0.6000  -80.4167
# 21         Georgetown      MY     78.89   5.4112  100.3354
# 26             Atuona      PF     77.94  -9.8000 -139.0333
#
#                      Hotel Name
# 1                quinta antigua
# 7   Halane Hotel and Restaurent
# 18          Saiananda Eco-Hotel
# 21               Cititel Penang
# 26                  Villa Enata

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
#add heatmap of temperature for the vacation spots
locations=hotel_df[["Lat","Lng"]]
max_temp=hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0,31.0),zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer=gmaps.marker_layer(locations,info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
z=[]
x={"test1":0,"test2": 1}
for i in x:
    z.append(i)
print(type(z))
# Out:
# <class 'list'>

# %%
y=[i for i in x]
print(type(y))
y
# Out:
# <class 'list'>
# ['test1', 'test2']
