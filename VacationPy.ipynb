# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
#from config import g_key
import sys
sys.path.append("C:/Users/laura/bootcamp/")
from api_keys import g_key

# %%
#read csv from weather data api
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City ID             City Country                 Date      Lat       Lng  \
# 0        0         Qaqortoq      GL  2021-12-20 22:01:55  60.7167  -46.0333
# 1        1  Lazaro Cardenas      MX  2021-12-20 22:01:56  17.9583 -102.2000
# 2        2             Dale      US  2021-12-20 22:01:57  38.1689  -86.9900
# 3        3  Nizhnyaya Poyma      RU  2021-12-20 22:01:57  56.1622   97.1933
# 4        4           Hobart      AU  2021-12-20 22:00:18 -42.8794  147.3294
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     50.50        72          71       14.12
# 1     83.41        64          25        7.09
# 2     42.58        65           1        3.44
# 3     -9.81        89         100        7.40
# 4     62.46        53          75       13.80

# %%
#city_data_df.dtypes

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)
fig = gmaps.figure()
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# fig2 = gmaps.figure()
# fig2

# %%
# get temperatures that are above 0
max_temp=city_data_df["Max Temp"]
temps=[]
for i in max_temp:
    temps.append(max(i,0))

# %%
# min_temp=0
# new_city_data_df=city_data_df.loc[city_data_df["Max Temp"]>=min_temp]
# new_city_data_df

# %%
# temps_series=pd.Series(temps)
# temps_series

# %%
#max temp heat map
#1. assign the locations to an array of latitiude and longitude pairs
locations=city_data_df[["Lat","Lng"]]
#2. assign the weights variable to some values
max_temp=city_data_df["Max Temp"]
#3. assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#4. assign the heatmap_layer varibale to the heatmap_layer attribute and add in the location
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp], 
                                 dissipating=False, max_intensity=300, point_radius=4)

#list comprehension
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp]

#add the heatmap layer
fig.add_layer(heat_layer)
#call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#humidity heat map
#1. assign the locations to an array of latitiude and longitude pairs
locations=city_data_df[["Lat","Lng"]]
#2. assign the weights variable to some values
humidity=city_data_df["Humidity"]
#3. assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#4. assign the heatmap_layer varibale to the heatmap_layer attribute and add in the location
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=300, point_radius=4)

#list comprehension
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp]

#add the heatmap layer
fig.add_layer(heat_layer)
#call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#cloudiness heat maps
#1. assign the locations to an array of latitiude and longitude pairs
locations=city_data_df[["Lat","Lng"]]
#2. assign the weights variable to some values
clouds=city_data_df["Cloudiness"]
#3. assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#4. assign the heatmap_layer varibale to the heatmap_layer attribute and add in the location
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, 
                                 dissipating=False, max_intensity=300, point_radius=4)

#list comprehension
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp]

#add the heatmap layer
fig.add_layer(heat_layer)
#call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#wind speed heat maps
#1. assign the locations to an array of latitiude and longitude pairs
locations=city_data_df[["Lat","Lng"]]
#2. assign the weights variable to some values
wind=city_data_df["Wind Speed"]
#3. assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations
fig=gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#4. assign the heatmap_layer varibale to the heatmap_layer attribute and add in the location
heat_layer = gmaps.heatmap_layer(locations, weights=wind, 
                                 dissipating=False, max_intensity=300, point_radius=4)

#list comprehension
#heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp]

#add the heatmap layer
fig.add_layer(heat_layer)
#call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City ID               City Country                 Date      Lat  \
# 1         1    Lazaro Cardenas      MX  2021-12-20 22:01:56  17.9583
# 7         7              Hobyo      SO  2021-12-20 22:01:59   5.3505
# 18       18  Bahia De Caraquez      EC  2021-12-20 22:02:07  -0.6000
# 21       21         Georgetown      MY  2021-12-20 22:02:08   5.4112
# 26       26             Atuona      PF  2021-12-20 22:02:10  -9.8000
# 32       32     Saint-Philippe      RE  2021-12-20 22:02:13 -21.3585
# 34       34            Kavieng      PG  2021-12-20 22:02:14  -2.5744
# 35       35          Bundaberg      AU  2021-12-20 22:02:15 -24.8500
# 38       38            Rikitea      PF  2021-12-20 22:02:16 -23.1203
# 41       41               Hilo      US  2021-12-20 21:58:31  19.7297
#
#          Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 1  -102.2000     83.41        64          25        7.09
# 7    48.5268     78.24        81          78       17.96
# 18  -80.4167     75.81        82         100        7.65
# 21  100.3354     78.89        87          20        0.00
# 26 -139.0333     77.94        72           1       10.92
# 32   55.7679     76.59        86          92        9.28
# 34  150.7967     82.69        76         100       13.24
# 35  152.3500     82.22        67          80        1.99
# 38 -134.9692     75.92        78         100       17.58
# 41 -155.0900     78.28         1          84        6.02

# %%
preferred_cities_df.count()
# Out:
# City ID       138
# City          138
# Country       137
# Date          138
# Lat           138
# Lng           138
# Max Temp      138
# Humidity      138
# Cloudiness    138
# Wind Speed    138
# dtype: int64

# %%
preferred_cities_df.isnull().sum()
# Out:
# City ID       0
# City          0
# Country       1
# Date          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# dtype: int64

# %%
#temps_series

# %%
# params = {
#     "radius": 5000,
#     "type": "lodging",
#     "key": g_key
# }

# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

#     # Make request and get the JSON data from the search. 
# test = requests.get(base_url, params=params).json()
# test

# %%
preferred_cities_new = preferred_cities_df.dropna()

# %%
preferred_cities_new.count()
# Out:
# City ID       137
# City          137
# Country       137
# Date          137
# Lat           137
# Lng           137
# Max Temp      137
# Humidity      137
# Cloudiness    137
# Wind Speed    137
# dtype: int64

# %%
#create dataframe called hotel_df to store hotel names along with city, country, max temp, and coordinates
hotel_df=preferred_cities_df[["City","Country","Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"]=""
hotel_df.head()
# Out:
#                  City Country  Max Temp      Lat       Lng Hotel Name
# 1     Lazaro Cardenas      MX     83.41  17.9583 -102.2000
# 7               Hobyo      SO     78.24   5.3505   48.5268
# 18  Bahia De Caraquez      EC     75.81  -0.6000  -80.4167
# 21         Georgetown      MY     78.89   5.4112  100.3354
# 26             Atuona      PF     77.94  -9.8000 -139.0333

# %%
#set parameters to search for a hotel
params={"radius":5000, "types": "lodging", "key":g_key}

# %%
#test for Paris
params_Paris={"radius":5000, "types": "lodging", "key":g_key,"location":"48.8566,2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#make request to get JSON from the search
hotels=requests.get(base_url,params=params_Paris).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEBN6jevcwZZb_Q9iQ2WMeGG0wIeeHaam-cFdU6cVsu5tLOQPjeKaM5fQOZ7BN9HHFh48N7Od1dYArOjlLlv9h9su7k7GZFrAh-kSuhQbd16Cy1h3MgkBa9bfkAyvu6GkJmTE6sMcHOQKsQVVL-zNISSHuweiZqMEDXFEKVvC7zMKDTrN5ZweCYgtABAWEVWjEMUOsVDfaaZc9NNyQ7me3RtsdpE8ruhwWpU_Ppv9A-ilNtsloUfu7KHmGFq1NO2gXG8uYMITylpEduKIHn4pXTieUvAK-_yDtBT0BquDskqV0Rqq-CZXkmMoXSiWtcNtFtyJPJFFpnSfd3EiMYP2M0_wSB_aejAdyQ-tlj4O4sdoQB0h5hjrjjeXNmyrxGQaZCSj54QtPhtLlWzut32flQFuAHq620jeXDU-edtVvYmacX9ElmLeWr4',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'Aap_uEALzRRNgOcKks4VW5k6NlLhdhP3TnnCHITjNTVcMl-iSLUqsNhcQL_tz0_6CS2bv5x9j5scWdBmmLB7bVYgzIa38iZ0Lon8iY8OqdgYuD_iPmHPtYCHhWqIuxPvpa8QfhWVlN6mXHMUavZlV31AtGKksGB-zN46GcYy_oe2cE6bzky2',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 314,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.85954748029151,
#       'lng': 2.347782830291502},
#      'southwest': {'lat': 48.85684951970851, 'lng': 2.345084869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Britannique - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1426,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>
Hôtel Regina Louvre</a>'],
#      'photo_reference': 'Aap_uEAMAd0xfFIyLbjHOPvpayPE8kA7OvY6kGWBhDSfge6yYYUaqguBwNfS2SQQYSN7MKVo_GPvkynaqPFOEmST_WN5qFxGkWKjwkrnykuTDYjcGbmuTcFPjpKtYu719wyaMKlQlWhd_Z0C2eBAAF0qSHQiSceg-_hVDBnSJ_NoV3caGNIn',
#      'width': 5550}],
#    'place_id': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'plus_code': {'compound_code': 'V87M+G2 Paris, France',
#     'global_code': '8FW4V87M+G2'},
#    'rating': 4.5,
#    'reference': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 508,
#    'vicinity': '2 Place des Pyramides, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84795229999999, 'lng': 2.370869},
#     'viewport': {'northeast': {'lat': 48.8492035302915,
#       'lng': 2.372290080291501},
#      'southwest': {'lat': 48.8465055697085, 'lng': 2.369592119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'ibis Paris Gare de Lyon Ledru Rollin 12ème',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101181280085797863615">Kevin Nguyen</a>'],
#      'photo_reference': 'Aap_uEBE3c2rf-bMqv-XMyCdEH3_ORRHgEqRp18ch0hpCBl0ln-OAvAjMV6_3X4hHzPRRgPpizHyaV3P9ZFC8jMtfqiOblF0LIZVmEgNk7O5HLUDqP2Vx--d3Vm2cYEIAODiPZFVGENp4pMzbwaIQGQyO9s3Tf3XBX4yVZOX4hMY-AVqSt0z',
#      'width': 1536}],
#    'place_id': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'plus_code': {'compound_code': 'R9XC+58 Paris, France',
#     'global_code': '8FW4R9XC+58'},
#    'rating': 4.1,
#    'reference': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 853,
#    'vicinity': '41/43 Avenue Ledru Rollin, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8710647, 'lng': 2.34991},
#     'viewport': {'northeast': {'lat': 48.87241888029151,
#       'lng': 2.351188530291502},
#      'southwest': {'lat': 48.86972091970851, 'lng': 2.348490569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel des Comédies Paris',
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114696623290303183213">Noble</a>'],
#      'photo_reference': 'Aap_uEAnmLaI4J2RhwKnyGKdKVSyb7TzIb9iFXfavlgVFAS31klqHlnBbvqtOUqxM5AjglMayGDrViS33ABLfLKBEMBTf5shcAEO0uvXJHr0eh7D6DH_ZZ6L_0QI_ygXUNfAHdvScmrs0Q9hLaAbMy5Admv5ldkBYQHPUlxTZ3tbGX0NfgQE',
#      'width': 3000}],
#    'place_id': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'plus_code': {'compound_code': 'V8CX+CX Paris, France',
#     'global_code': '8FW4V8CX+CX'},
#    'rating': 4.3,
#    'reference': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 200,
#    'vicinity': "8 Rue d'Hauteville, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84754640000001, 'lng': 2.3718722},
#     'viewport': {'northeast': {'lat': 48.8488820802915,
#       'lng': 2.373123430291502},
#      'southwest': {'lat': 48.8461841197085, 'lng': 2.370425469708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel De France Gare de Lyon Bastille',
#    'photos': [{'height': 787,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117462031751048846575">Hôtel De France Gare de Lyon Bastille</a>'],
#      'photo_reference': 'Aap_uEBoz5wdtkdjPS2hlSmae6OjeFSYex2Vzqwlr8WsWkhgllDoNLFhGHuMVtP3QY1aHBMD4EcKyZwHajkQgrOUbHZoKQa29TkyrzTDGSgIc1qRgXp_1tQwK_-59T0kwsFMpRTjZT1ByN7aoPqIpw9K2wJy40tCiGxHOv9xy3p3Qoqltq8u',
#      'width': 1181}],
#    'place_id': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'plus_code': {'compound_code': 'R9XC+2P Paris, France',
#     'global_code': '8FW4R9XC+2P'},
#    'rating': 3.3,
#    'reference': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 382,
#    'vicinity': '12 Rue de Lyon, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8717386, 'lng': 2.3447052},
#     'viewport': {'northeast': {'lat': 48.8731374802915,
#       'lng': 2.346059980291502},
#      'southwest': {'lat': 48.8704395197085, 'lng': 2.343362019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Prélude Opéra Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106224131803115407650">Marcin Marczak</a>'],
#      'photo_reference': 'Aap_uEBd5GTxq4ktId_uiu3OlmW3mCsdhJaETbDo2vo5phIyyld9W5d0aZdPcZwiaIwZTOvZR7CAV0s2nidLIMWHknaCSB8hYxQh1kYh1X0tw9z-0wUYrUcugyc-hWqAuwid40JTVof485B8GezHe2zdWorH8tyyZ1aBC8ZDQqjWv1ArC5iH',
#      'width': 3264}],
#    'place_id': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'plus_code': {'compound_code': 'V8CV+MV Paris, France',
#     'global_code': '8FW4V8CV+MV'},
#    'rating': 

#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105830788751825835396">Peter Sheehan</a>'],
#      'photo_reference': 'Aap_uEAfXY8fyf5UXI_dtq3Cwfo6PK5-BNsKIeJbKo4rEsmKyiqZxpzbrBXZinHqGR08f9oFSr0xgBMIXwjC8HG1NVma1_EabgHUWDtrP8AHjNyx5fcuuNlqvOSnTc3zYpKwDYyCcVTJcapshRo-Crapk_F9exUwA-bSQq8GiKLSg_KC9Vbn',
#      'width': 1080}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.5,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 297,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8547358, 'lng': 2.3395366},
#     'viewport': {'northeast': {'lat': 48.8561113302915,
#       'lng': 2.340816080291502},
#      'southwest': {'lat': 48.85341336970851, 'lng': 2.338118119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Hôtel d'Aubusson",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4431,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115702439863948549296">Hôtel d&#39;Aubusson Paris</a>'],
#      'photo_reference': 'Aap_uEC4kFgWXf_mW7WKvK8PdDRSQD9aZI0ptUEsLroIBX2jIFuR_6c_a83l7IFvcoxwaCjqoSlL86VzEwmCNBQIPYsHq1cO2aVY6adgozgDUP-JOwXD3-t8awqRSBKqLDuY60NoH1fE2TPQJE6lMg5l6fTkmfDqvk_BoJ2F5PuqjJU-APtV',
#      'width': 6631}],
#    'place_id': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'plus_code': {'compound_code': 'V83Q+VR Paris, France',
#     'global_code': '8FW4V83Q+VR'},
#    'rating': 4.7,
#    'reference': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 306,
#    'vicinity': '33 Rue Dauphine, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.8531470802915,
#       'lng': 2.346121880291502},
#      'southwest': {'lat': 48.8504491197085, 'lng': 2.343423919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'Aap_uEAj6-pdvmREoMBHwfl9qXHlHZbZXx92EyH9hsVmjMLXPL4dSGOgN-EXSJfZruIQ9Z1TA-EC2UYo4kBEByTLNRM8Qt0SdaZa9UciXcXLM33xSNoXPVqVSJlRowQRm_xb1hE9Pmt0rNzakspiW74kU5f227IrzNinD-HkyxmrM0QSYd5H',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 155,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 20

# %%
hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'

# %%
#iterate through the dataframe
for index, row in hotel_df.iterrows():
    #get latitude and longitude
    lat=row["Lat"]
    lng=row["Lng"]
    
    #add lat and lng to location keey for the params dictionary
    params["location"]=f"{lat},{lng}"
    
    #use the search term "lodging" and lat and lng
    base_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    #make request for json
    hotels=requests.get(base_url,params=params).json()
    #grad first hotel from the results and store the name
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping")
# Out:
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping
# Hotel not found... skipping

# %%
hotel_df.head()
# Out:
#                  City Country  Max Temp      Lat       Lng  \
# 1     Lazaro Cardenas      MX     83.41  17.9583 -102.2000
# 7               Hobyo      SO     78.24   5.3505   48.5268
# 18  Bahia De Caraquez      EC     75.81  -0.6000  -80.4167
# 21         Georgetown      MY     78.89   5.4112  100.3354
# 26             Atuona      PF     77.94  -9.8000 -139.0333
#
#                      Hotel Name
# 1                quinta antigua
# 7   Halane Hotel and Restaurent
# 18          Saiananda Eco-Hotel
# 21               Cititel Penang
# 26                  Villa Enata

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
#add heatmap of temperature for the vacation spots
locations=hotel_df[["Lat","Lng"]]
max_temp=hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0,31.0),zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer=gmaps.marker_layer(locations,info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
