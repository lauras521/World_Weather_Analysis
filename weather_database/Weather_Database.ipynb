# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests as req
import time
from datetime import datetime
from scipy.stats import linregress

# Google developer API key
import sys
sys.path.append("C:/Users/laura/bootcamp/")
from api_keys import g_key

#weather api key
sys.path.append("C:/Users/laura/bootcamp/")
from api_keys import weather_api_key

# %%
#create a set of random latitudes and longitude combinations for 2000 points
lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs
#zip puts objects into a tuple

# %%
#add latitudes and longitudes to a list
coordinates=list(lat_lngs)

# %%
#create a list to hold the cities
cities=[]
#identify the nearest city for each latitude and longitude combination
for i in coordinates:
    city=(citipy.nearest_city(i[0], i[1]).city_name)
    #if city is unique add it to the list
    if city not in cities:
        cities.append(city)
#print to confirm count
len(cities)
cities
# Out:
# ['jackson',
#  'campina grande do sul',
#  'luderitz',
#  'ilulissat',
#  'albany',
#  'santa maria del oro',
#  'lavrentiya',
#  'tiksi',
#  'ushuaia',
#  'daboh',
#  'alugan',
#  'yunyang',
#  'castro',
#  'belushya guba',
#  'cape town',
#  'kodiak',
#  'at-bashi',
#  'busselton',
#  'guerrero negro',
#  'vaini',
#  'joaquim nabuco',
#  'mys shmidta',
#  'kahului',
#  'barrow',
#  'upernavik',
#  'punta arenas',
#  'statesboro',
#  'matamoros',
#  'ilula',
#  'morondava',
#  'chokurdakh',
#  'butaritari',
#  'illoqqortoormiut',
#  'hermanus',
#  'saint-philippe',
#  'hobart',
#  'khatanga',
#  'namyslow',
#  'rocha',
#  'longyearbyen',
#  'norman wells',
#  'rumford',
#  'tessalit',
#  'pevek',
#  'merauke',
#  'barentsburg',
#  'kismayo',
#  'qaanaaq',
#  'libertador general san martin',
#  'bubaque',
#  'mahebourg',
#  'lebu',
#  'dunedin',
#  'luwuk',
#  'artyk',
#  'rikitea',
#  'port alfred',
#  'monrovia',
#  'saldanha',
#  'jamestown',
#  'hithadhoo',
#  'okhotsk',
#  'ribeira grande',
#  'kapaa',
#  'kitob',
#  'atuona',
#  'paranhos',
#  'cherskiy',
#  'dawson creek',
#  'hasaki',
#  'presidencia roque saenz pena',
#  'korla',
#  'new norfolk',
#  'cidreira',
#  'menongue',
#  'amderma',
#  'yellowknife',
#  'horlivka',
#  'vitimskiy',
#  'todos santos',
#  'east london',
#  'ulladulla',
#  'midland',
#  'taolanaro',
#  'tuktoyaktuk',
#  'bluff',
#  'port augusta',
#  'tautira',
#  'mataura',
#  'georgetown',
#  'oistins',
#  'laguna',
#  'ahipara',
#  'kijang',
#  'los llanos de aridane',
#  'kazalinsk',
#  'san pedro',
#  'port moresby',
#  'cabo san lucas',
#  'sao joao da barra',
#  'dumas',
#  'oskemen',
#  'tasiilaq',
#  'chifeng',
#  'matagami',
#  'grand gaube',
#  'taywarah',
#  'sorvag',
#  'nikolskoye',
#  'nemuro',
#  'kolyshley',
#  'bengkulu',
#  'sosenskiy',
#  'marsaxlokk',
#  'ust-omchug',
#  'srednekolymsk',
#  'la rioja',
#  'yarmouth',
#  'meulaboh',
#  'san patricio',
#  'dingle',
#  'lexington',
#  'saskylakh',
#  'sur',
#  'searcy',
#  'formosa',
#  'yilan',
#  'kytlym',
#  'bredasdorp',
#  'bambous virieux',
#  'flinders',
#  'puerto ayacucho',
#  'mortka',
#  'caravelas',
#  'arraial do cabo',
#  'zeya',
#  'tay ninh',
#  'loralai',
#  'port elizabeth',
#  'hilo',
#  'thompson',
#  'uruzgan',
#  'aklavik',
#  'carnarvon',
#  'jacareacanga',
#  'khonuu',
#  'vila',
#  'richards bay',
#  'hillsboro',
#  'tiznit',
#  'salamiyah',
#  'tubuala',
#  'vao',
#  'bethel',
#  'esperance',
#  'anadyr',
#  'codrington',
#  'hun',
#  'severo-kurilsk',
#  'anshun',
#  'vestmannaeyjar',
#  'punta',
#  'iqaluit',
#  'beringovskiy',
#  'svetlogorsk',
#  'faya',
#  'vila velha',
#  'pimentel',
#  'khalkhal',
#  'narita',
#  'muros',
#  'bouna',
#  'torbay',
#  'martapura',
#  'yungkang',
#  'paralia',
#  'kavieng',
#  'batagay',
#  'grand river south east',
#  'avarua',
#  'lompoc',
#  'haapu',
#  'kurakh',
#  'panguna',
#  'kamenskoye',
#  'paracelis',
#  'innisfail',
#  'sri aman',
#  'evensk',
#  'paamiut',
#  'kamp-lintfort',
#  'chikoy',
#  'ranghulu',
#  'lesnoy',
#  'crab hill',
#  'tuatapere',
#  'talnakh',
#  'gravelbourg',
#  'saint george',
#  'avera',
#  'kisoro',
#  'cayenne',
#  'mar del plata',
#  'kununurra',
#  'kutum',
#  'mount gambier',
#  'college',
#  'louisbourg',
#  'songjianghe',
#  'dongsheng',
#  'coahuayana',
#  'tumannyy',
#  'tazovskiy',
#  'bandiagara',
#  'chuy',
#  'nishihara',
#  'milkovo',
#  'batticaloa',
#  'provideniya',
#  'oranjemund',
#  'najran',
#  'hami',
#  'luba',
#  'new pitsligo',
#  'la ronge',
#  'broome',
#  'husavik',
#  'salalah',
#  'mexico',
#  'middletown',
#  'olafsvik',
#  'abrau-dyurso',
#  'byron bay',
#  'baculin',
#  'zvishavane',
#  'dikson',
#  'airai',
#  'kattivakkam',
#  'tsihombe',
#  'roald',
#  'zhezkazgan',
#  'grindavik',
#  'faanui',
#  'progreso',
#  'attawapiskat',
#  'cortez',
#  'kaeo',
#  'raudeberg',
#  'sand springs',
#  'berlevag',
#  'biak',
#  'ngukurr',
#  'sibolga',
#  'japura',
#  'ardakan',
#  'ishigaki',
#  'iberia',
#  'sioux lookout',
#  'puerto escondido',
#  'klaksvik',
#  'arcoverde',
#  'turayf',
#  'mecca',
#  'bonavista',
#  'ouesso',
#  'carballo',
#  'san quintin',
#  'kenai',
#  'lolua',
#  'udachnyy',
#  'wahran',
#  'rock sound',
#  'marang',
#  'manoel urbano',
#  'kangaatsiaq',
#  'almaznyy',
#  'tabou',
#  'zlobin',
#  'tiarei',
#  'kroderen',
#  'comodoro rivadavia',
#  'te karaka',
#  'panzhihua',
#  'tombouctou',
#  'lanzhou',
#  'kurtamysh',
#  'port hardy',
#  'aranos',
#  'quatre cocos',
#  'victoria',
#  'vardo',
#  'saryshagan',
#  'verkhoyansk',
#  'magway',
#  'santa cruz',
#  'williamsport',
#  'muzhi',
#  'puerto ayora',
#  'bathsheba',
#  'bartlett',
#  'sorong',
#  'mendahara',
#  'turukhansk',
#  'dalbandin',
#  'miramar',
#  'vanavara',
#  'hvide sande',
#  'kastamonu',
#  'klyuchi',
#  'banes',
#  'garowe',
#  'sourpi',
#  'puerto maldonado',
#  'mayo',
#  'namibe',
#  'oussouye',
#  'songea',
#  'agadez',
#  'nanortalik',
#  'limon',
#  'jamtara',
#  'arkhangelos',
#  'lebowakgomo',
#  'shagonar',
#  'tawkar',
#  'batagay-alyta',
#  'isangel',
#  'santa eulalia del rio',
#  'yulara',
#  'harlingen',
#  'manzhouli',
#  'york',
#  'odiongan',
#  'gat',
#  'henties bay',
#  'awbari',
#  'baiyin',
#  'nouadhibou',
#  'nizhneyansk',
#  'portland',
#  'kirkwall',
#  'ponnani',
#  'rincon',
#  'fortuna',
#  'marawi',
#  'magdalena',
#  'sukumo',
#  'petropavlovsk-kamchatskiy',
#  'jawhar',
#  'betki',
#  'buchanan',
#  'ashta',
#  'nha trang',
#  'palmer',
#  'belyy yar',
#  'sitka',
#  'aleksandrovskoye',
#  'oskarshamn',
#  'pasighat',
#  'mnogovershinnyy',
#  'sheridan',
#  'ruatoria',
#  'champerico',
#  'katsuura',
#  'hit',
#  'kaitangata',
#  'new ulm',
#  'bilma',
#  'narsaq',
#  'rungata',
#  'maumere',
#  'port keats',
#  'surskoye',
#  'vanimo',
#  'bolungarvik',
#  'jalingo',
#  'omboue',
#  'kamyshevatskaya',
#  'mancio lima',
#  'chipinge',
#  'samusu',
#  'ponta do sol',
#  'santander',
#  'santa rosalia',
#  'borovskoy',
#  'samarai',
#  'khakhea',
#  'ketchikan',
#  'shaowu',
#  'viedma',
#  'winston-salem',
#  'wajir',
#  'qarayeri',
#  'alofi',
#  'sumbawa',
#  'ambon',
#  'ascension',
#  'mehran',
#  'ngunguru',
#  'tupancireta',
#  'itaituba',
#  'egvekinot',
#  'urubicha',
#  'rumoi',
#  'sosua',
#  'sept-iles',
#  'porto nacional',
#  'kushiro',
#  'sawakin',
#  'la plaine',
#  'kabare',
#  'zaozerne',
#  'shahr-e babak',
#  'clyde river',
#  'tateyama',
#  'sentyabrskiy',
#  'marcona',
#  'poum',
#  'vila franca do campo',
#  'sao filipe',
#  'ancud',
#  'kuito',
#  'srivardhan',
#  'mahon',
#  'balkhash',
#  'odoyev',
#  'nantucket',
#  'sola',
#  'copala',
#  'sayat',
#  'pemba',
#  'vaitupu',
#  'ayagoz',
#  'cintalapa',
#  'rondonopolis',
#  'bambanglipuro',
#  'cockburn town',
#  'hambantota',
#  'uzumlu',
#  'yazykovo',
#  'ilhabela',
#  'kargasok',
#  'kruisfontein',
#  'luanda',
#  'bara',
#  'visby',
#  'poshekhonye',
#  'zaysan',
#  'matay',
#  'aleksandrov gay',
#  'murashi',
#  'daru',
#  'te anau',
#  'floro',
#  'ixtapa',
#  'fort-shevchenko',
#  'qingyuan',
#  'sidhi',
#  'marv dasht',
#  'bima',
#  'komsomolskiy',
#  'buala',
#  'altamont',
#  'volary',
#  'bontang',
#  'killybegs',
#  'chunhuhub',
#  'saint anthony',
#  'dongying',
#  'port hawkesbury',
#  'adrar',
#  'kalvarija',
#  'mao',
#  'san lawrenz',
#  'dwarka',
#  'naze',
#  'saleaula',
#  'amlimay',
#  'turka',
#  'shingu',
#  'shimoda',
#  'palabuhanratu',
#  'the valley',
#  'xining',
#  'lamu',
#  'mabini',
#  'mugur-aksy',
#  'clinton',
#  'antofagasta',
#  'umzimvubu',
#  'joshimath',
#  'gornoye loo',
#  'souillac',
#  'winnemucca',
#  'honiara',
#  'hermagor',
#  'vermillion',
#  'flin flon',
#  'tsienyane',
#  'krasnokamensk',
#  'gouyave',
#  'havoysund',
#  'abu dhabi',
#  'obluche',
#  'skibbereen',
#  'inhambane',
#  'upata',
#  'yuty',
#  'usinsk',
#  'kholodnyy',
#  'amatlan',
#  'semey',
#  'lumeje',
#  'villa bruzual',
#  'axim',
#  'yerbogachen',
#  'huizhou',
#  'chkalovskoye',
#  'constitucion',
#  'karamay',
#  'sikonge',
#  'hay river',
#  'nioro',
#  'cartagena',
#  'west wendover',
#  'lincoln',
#  'charagua',
#  'seymchan',
#  'olavarria',
#  'maningrida',
#  'yerofey pavlovich',
#  'yar-sale',
#  'touros',
#  'siauliai',
#  'kempsey',
#  'fortuna foothills',
#  'la romana',
#  'tomatlan',
#  'valparaiso',
#  'rozkishne',
#  'cam ranh',
#  'wheeling',
#  'mount isa',
#  'luganville',
#  'kampot',
#  'acapulco',
#  'maridi',
#  'shu',
#  'coos bay',
#  'geraldton',
#  'porto walter',
#  'hofn',
#  'yartsevo',
#  'galveston',
#  'tondano',
#  'san policarpo',
#  'emerald',
#  'okandja',
#  'saint-pierre',
#  'houma',
#  'maykain',
#  'ambilobe',
#  'lampang',
#  'porto seguro',
#  'labuhan',
#  'tecate',
#  'nelson bay',
#  'lasa',
#  'lagoa',
#  'umm kaddadah',
#  'ust-maya',
#  'sarahan',
#  'puri',
#  'tabas',
#  'nalut',
#  'plouzane',
#  'leh',
#  'tromso',
#  'praia',
#  'capitan bado',
#  'warrington',
#  'itoman',
#  'fairlie',
#  'nuuk',
#  'gawler',
#  'teguldet',
#  'mehamn',
#  'ler',
#  'raga',
#  'otane',
#  'qaqortoq',
#  'bibiani',
#  'bhadasar',
#  'ternate',
#  'alotau',
#  'hovd',
#  'jadu',
#  'oksfjord',
#  'ugoofaaru',
#  'darhan',
#  'khem karan',
#  'margate',
#  'batemans bay',
#  'voyvozh',
#  'fonte boa',
#  'phan thiet',
#  'aswan',
#  'harper',
#  'berdigestyakh',
#  'ballstad',
#  'dzhusaly',
#  'iwaki',
#  'warrnambool',
#  'waipawa',
#  'isabela',
#  'oyama',
#  'pangnirtung',
#  'leningradskiy',
#  'suntar',
#  'savalou',
#  'wangqing',
#  'winona',
#  'birobidzhan',
#  'salento',
#  'miri',
#  'roanoke rapids',
#  'half moon bay',
#  'general pico',
#  'halalo',
#  'wundanyi',
#  'tlyarota',
#  'burica',
#  'avon',
#  'polyarnyy',
#  'esso',
#  'haines junction',
#  'port lincoln',
#  'quelimane',
#  'terra santa',
#  'urumqi',
#  'doctor pedro p. pena',
#  'cap malheureux',
#  'bondoukou',
#  'ankang',
#  'rongcheng',
#  'mogadishu',
#  'taltal',
#  'porto santo',
#  'barguzin',
#  'san cristobal',
#  'torres',
#  'teluknaga',
#  'kamareddi',
#  'nanga eboko',
#  'ada',
#  'juneau',
#  'leshukonskoye',
#  'naica',
#  'cabinda',
#  'huanren',
#  'thaton',
#  'guozhen',
#  'abu kamal',
#  'acari',
#  'hammerfest',
#  'horta',
#  'estevan',
#  'gwanda',
#  'tankhoy',
#  'yuxia',
#  'brive-la-gaillarde',
#  'port macquarie',
#  'tornio',
#  'santa luzia',
#  'price',
#  'miandrivazo',
#  'kungurtug',
#  'barcelona',
#  'hamilton',
#  'madimba',
#  'iwanai',
#  'vetluga',
#  'dicabisagan',
#  'yenagoa',
#  'el wasta',
#  'ossora',
#  'kavaratti',
#  'fort nelson',
#  'filadelfia',
#  'kolo',
#  'kapoeta',
#  'tabialan',
#  'myitkyina',
#  'coihaique',
#  'hare bay',
#  'lata',
#  'tatawin',
#  'montepuez',
#  'tasbuget',
#  'betare oya',
#  'constantine',
#  'dzilam gonzalez',
#  'biltine',
#  'baykit',
#  'durango',
#  'ewa beach',
#  'san javier',
#  'inongo',
#  'lisakovsk',
#  'palu',
#  'suao',
#  'hailar',
#  'yarkovo',
#  'fond du lac',
#  'griffith',
#  'artyom',
#  'aberdeen',
#  'inirida',
#  'saint-louis',
#  'foxton',
#  'lorengau',
#  'siniscola',
#  'obidos',
#  'council bluffs',
#  'oudtshoorn',
#  'vostok',
#  'karratha',
#  'bembereke',
#  'deputatskiy',
#  'along',
#  'sistranda',
#  'dawei',
#  'havre-saint-pierre',
#  'rumphi',
#  'mandurah',
#  'concarneau',
#  'magadi',
#  'kailua',
#  'varna',
#  'odweyne',
#  'amapa',
#  'corrente',
#  'kobryn',
#  'simojovel',
#  'cefalu',
#  'nyrob',
#  'khandyga',
#  'bousso',
#  'robertson',
#  'ndioum',
#  'manakara',
#  'yuzhno-yeniseyskiy',
#  'akranes']

# %%
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
## Create an endpoint URL for a city.
#city_url = url + "&q=" + city

# %%
#create an empty list to hold city data
city_data=[]
#print the beginning of the logging
print("Beginning Data Retrieval      ")
print("-----------------------------")

#create counters
record_count=1
set_count=1
#loop through all cities in our list:
#enumerate iterates through list of cities and retrieves both the index and the city from the list
for i, city in enumerate(cities):
    #group cities in sets of 50 for logging purposes
    if (i % 50==0 and i>=50):
        set_count+=1
        record_count=1
        #prgram pauses for 60 seconds you can only do 50 calls per minutes on OpenWeatherMap API free version
        time.sleep(60)
        
    #create endpoint URL with each city
    city_url= url + "&q=" + city.replace(" ","+")
        
    #log the URL, record, and set the numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #add 1 to the record count
    record_count+=1

        
#run an API request for each of the cities
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_current_description})
            # If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jackson
# Processing Record 2 of Set 1 | campina grande do sul
# Processing Record 3 of Set 1 | luderitz
# Processing Record 4 of Set 1 | ilulissat
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | santa maria del oro
# Processing Record 7 of Set 1 | lavrentiya
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | daboh
# Processing Record 11 of Set 1 | alugan
# Processing Record 12 of Set 1 | yunyang
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | at-bashi
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | guerrero negro
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | joaquim nabuco
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | kahului
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | statesboro
# Processing Record 28 of Set 1 | matamoros
# Processing Record 29 of Set 1 | ilula
# Processing Record 30 of Set 1 | morondava
# Processing Record 31 of Set 1 | chokurdakh
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | namyslow
# Processing Record 39 of Set 1 | rocha
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | norman wells
# Processing Record 42 of Set 1 | rumford
# Processing Record 43 of Set 1 | tessalit
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | merauke
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | kismayo
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | libertador general san martin
# Processing Record 50 of Set 1 | bubaque
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | dunedin
# Processing Record 4 of Set 2 | luwuk
# Processing Record 5 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | monrovia
# Processing Record 9 of Set 2 | saldanha
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | okhotsk
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | kitob
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | paranhos
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | dawson creek
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | presidencia roque saenz pena
# Processing Record 22 of Set 2 | korla
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | cidreira
# Processing Record 25 of Set 2 | menongue
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | horlivka
# Processing Record 29 of Set 2 | vitimskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | todos santos
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | ulladulla
# Processing Record 33 of Set 2 | midland
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | port augusta
# Processing Record 38 of Set 2 | tautira
# Processing Record 39 of Set 2 | mataura
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | oistins
# Processing Record 42 of Set 2 | laguna
# Processing Record 43 of Set 2 | ahipara
# Processing Record 44 of Set 2 | kijang
# Processing Record 45 of Set 2 | los llanos de aridane
# Processing Record 46 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 2 | san pedro
# Processing Record 48 of Set 2 | port moresby
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 50 of Set 2 | sao joao da barra
# Processing Record 1 of Set 3 | dumas
# Processing Record 2 of Set 3 | oskemen
# Processing Record 3 of Set 3 | tasiilaq
# Processing Record 4 of Set 3 | chifeng
# Processing Record 5 of Set 3 | matagami
# Processing Record 6 of Set 3 | grand gaube
# Processing Record 7 of Set 3 | taywarah
# Processing Record 8 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | nemuro
# Processing Record 11 of Set 3 | kolyshley
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | sosenskiy
# Processing Record 14 of Set 3 | marsaxlokk
# Processing Record 15 of Set 3 | ust-omchug
# Processing Record 16 of Set 3 | srednekolymsk
# Processing Record 17 of Set 3 | la rioja
# Processing Record 18 of Set 3 | yarmouth
# Processing Record 19 of Set 3 | meulaboh
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | dingle
# Processing Record 22 of Set 3 | lexington
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | sur
# Processing Record 25 of Set 3 | searcy
# Processing Record 26 of Set 3 | formosa
# Processing Record 27 of Set 3 | yilan
# Processing Record 28 of Set 3 | kytlym
# City not found. Skipping...
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | flinders
# Processing Record 32 of Set 3 | puerto ayacucho
# Processing Record 33 of Set 3 | mortka
# Processing Record 34 of Set 3 | caravelas
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | zeya
# Processing Record 37 of Set 3 | tay ninh
# Processing Record 38 of Set 3 | loralai
# Processing Record 39 of Set 3 | port elizabeth
# Processing Record 40 of Set 3 | hilo
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | uruzgan
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | carnarvon
# Processing Record 45 of Set 3 | jacareacanga
# Processing Record 46 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 3 | vila
# Processing Record 48 of Set 3 | richards bay
# Processing Record 49 of Set 3 | hillsboro
# Processing Record 50 of Set 3 | tiznit
# Processing Record 1 of Set 4 | salamiyah
# Processing Record 2 of Set 4 | tubuala
# Processing Record 3 of Set 4 | vao
# Processing Record 4 of Set 4 | bethel
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | anadyr
# Processing Record 7 of Set 4 | codrington
# Processing Record 8 of Set 4 | hun
# Processing Record 9 of Set 4 | severo-kurilsk
# Processing Record 10 of Set 4 | anshun
# Processing Record 11 of Set 4 | vestmannaeyjar
# Processing Record 12 of Set 4 | punta
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | beringovskiy
# Processing Record 15 of Set 4 | svetlogorsk
# Processing Record 16 of Set 4 | faya
# Processing Record 17 of Set 4 | vila velha
# Processing Record 18 of Set 4 | pimentel
# Processing Record 19 of Set 4 | khalkhal
# Processing Record 20 of Set 4 | narita
# Processing Record 21 of Set 4 | muros
# Processing Record 22 of Set 4 | bouna
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | martapura
# Processing Record 25 of Set 4 | yungkang
# City not found. Skipping...
# Processing Record 26 of Set 4 | paralia
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | batagay
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | avarua
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | haapu
# City not found. Skipping...
# Processing Record 33 of Set 4 | kurakh
# Processing Record 34 of Set 4 | panguna
# Processing Record 35 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 4 | paracelis
# Processing Record 37 of Set 4 | innisfail
# Processing Record 38 of Set 4 | sri aman
# Processing Record 39 of Set 4 | evensk
# Processing Record 40 of Set 4 | paamiut
# Processing Record 41 of Set 4 | kamp-lintfort
# Processing Record 42 of Set 4 | chikoy
# City not found. Skipping...
# Processing Record 43 of Set 4 | ranghulu
# Processing Record 44 of Set 4 | lesnoy
# Processing Record 45 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | gravelbourg
# Processing Record 49 of Set 4 | saint george
# Processing Record 50 of Set 4 | avera
# Processing Record 1 of Set 5 | kisoro
# Processing Record 2 of Set 5 | cayenne
# Processing Record 3 of Set 5 | mar del plata
# Processing Record 4 of Set 5 | kununurra
# Processing Record 5 of Set 5 | kutum
# Processing Record 6 of Set 5 | mount gambier
# Processing Record 7 of Set 5 | college
# Processing Record 8 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 5 | songjianghe
# Processing Record 10 of Set 5 | dongsheng
# Processing Record 11 of Set 5 | coahuayana
# Processing Record 12 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 5 | tazovskiy
# Processing Record 14 of Set 5 | bandiagara
# Processing Record 15 of Set 5 | chuy
# Processing Record 16 of Set 5 | nishihara
# Processing Record 17 of Set 5 | milkovo
# Processing Record 18 of Set 5 | batticaloa
# Processing Record 19 of Set 5 | provideniya
# Processing Record 20 of Set 5 | oranjemund
# Processing Record 21 of Set 5 | najran
# Processing Record 22 of Set 5 | hami
# Processing Record 23 of Set 5 | luba
# Processing Record 24 of Set 5 | new pitsligo
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | broome
# Processing Record 27 of Set 5 | husavik
# Processing Record 28 of Set 5 | salalah
# Processing Record 29 of Set 5 | mexico
# Processing Record 30 of Set 5 | middletown
# Processing Record 31 of Set 5 | olafsvik
# Processing Record 32 of Set 5 | abrau-dyurso
# Processing Record 33 of Set 5 | byron bay
# Processing Record 34 of Set 5 | baculin
# Processing Record 35 of Set 5 | zvishavane
# Processing Record 36 of Set 5 | dikson
# Processing Record 37 of Set 5 | airai
# Processing Record 38 of Set 5 | kattivakkam
# Processing Record 39 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 5 | roald
# Processing Record 41 of Set 5 | zhezkazgan
# Processing Record 42 of Set 5 | grindavik
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | progreso
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | cortez
# Processing Record 47 of Set 5 | kaeo
# Processing Record 48 of Set 5 | raudeberg
# Processing Record 49 of Set 5 | sand springs
# Processing Record 50 of Set 5 | berlevag
# Processing Record 1 of Set 6 | biak
# Processing Record 2 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 6 | sibolga
# Processing Record 4 of Set 6 | japura
# Processing Record 5 of Set 6 | ardakan
# Processing Record 6 of Set 6 | ishigaki
# Processing Record 7 of Set 6 | iberia
# Processing Record 8 of Set 6 | sioux lookout
# Processing Record 9 of Set 6 | puerto escondido
# Processing Record 10 of Set 6 | klaksvik
# Processing Record 11 of Set 6 | arcoverde
# Processing Record 12 of Set 6 | turayf
# Processing Record 13 of Set 6 | mecca
# Processing Record 14 of Set 6 | bonavista
# Processing Record 15 of Set 6 | ouesso
# Processing Record 16 of Set 6 | carballo
# Processing Record 17 of Set 6 | san quintin
# Processing Record 18 of Set 6 | kenai
# Processing Record 19 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 6 | udachnyy
# Processing Record 21 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 22 of Set 6 | rock sound
# Processing Record 23 of Set 6 | marang
# Processing Record 24 of Set 6 | manoel urbano
# Processing Record 25 of Set 6 | kangaatsiaq
# Processing Record 26 of Set 6 | almaznyy
# Processing Record 27 of Set 6 | tabou
# Processing Record 28 of Set 6 | zlobin
# Processing Record 29 of Set 6 | tiarei
# Processing Record 30 of Set 6 | kroderen
# City not found. Skipping...
# Processing Record 31 of Set 6 | comodoro rivadavia
# Processing Record 32 of Set 6 | te karaka
# Processing Record 33 of Set 6 | panzhihua
# Processing Record 34 of Set 6 | tombouctou
# Processing Record 35 of Set 6 | lanzhou
# Processing Record 36 of Set 6 | kurtamysh
# Processing Record 37 of Set 6 | port hardy
# Processing Record 38 of Set 6 | aranos
# Processing Record 39 of Set 6 | quatre cocos
# Processing Record 40 of Set 6 | victoria
# Processing Record 41 of Set 6 | vardo
# Processing Record 42 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 6 | verkhoyansk
# Processing Record 44 of Set 6 | magway
# Processing Record 45 of Set 6 | santa cruz
# Processing Record 46 of Set 6 | williamsport
# Processing Record 47 of Set 6 | muzhi
# Processing Record 48 of Set 6 | puerto ayora
# Processing Record 49 of Set 6 | bathsheba
# Processing Record 50 of Set 6 | bartlett
# Processing Record 1 of Set 7 | sorong
# Processing Record 2 of Set 7 | mendahara
# City not found. Skipping...
# Processing Record 3 of Set 7 | turukhansk
# Processing Record 4 of Set 7 | dalbandin
# Processing Record 5 of Set 7 | miramar
# Processing Record 6 of Set 7 | vanavara
# Processing Record 7 of Set 7 | hvide sande
# Processing Record 8 of Set 7 | kastamonu
# Processing Record 9 of Set 7 | klyuchi
# Processing Record 10 of Set 7 | banes
# Processing Record 11 of Set 7 | garowe
# Processing Record 12 of Set 7 | sourpi
# Processing Record 13 of Set 7 | puerto maldonado
# Processing Record 14 of Set 7 | mayo
# Processing Record 15 of Set 7 | namibe
# Processing Record 16 of Set 7 | oussouye
# Processing Record 17 of Set 7 | songea
# Processing Record 18 of Set 7 | agadez
# Processing Record 19 of Set 7 | nanortalik
# Processing Record 20 of Set 7 | limon
# Processing Record 21 of Set 7 | jamtara
# Processing Record 22 of Set 7 | arkhangelos
# City not found. Skipping...
# Processing Record 23 of Set 7 | lebowakgomo
# Processing Record 24 of Set 7 | shagonar
# Processing Record 25 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 26 of Set 7 | batagay-alyta
# Processing Record 27 of Set 7 | isangel
# Processing Record 28 of Set 7 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 29 of Set 7 | yulara
# Processing Record 30 of Set 7 | harlingen
# Processing Record 31 of Set 7 | manzhouli
# Processing Record 32 of Set 7 | york
# Processing Record 33 of Set 7 | odiongan
# Processing Record 34 of Set 7 | gat
# Processing Record 35 of Set 7 | henties bay
# Processing Record 36 of Set 7 | awbari
# Processing Record 37 of Set 7 | baiyin
# Processing Record 38 of Set 7 | nouadhibou
# Processing Record 39 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 7 | portland
# Processing Record 41 of Set 7 | kirkwall
# Processing Record 42 of Set 7 | ponnani
# Processing Record 43 of Set 7 | rincon
# Processing Record 44 of Set 7 | fortuna
# Processing Record 45 of Set 7 | marawi
# Processing Record 46 of Set 7 | magdalena
# Processing Record 47 of Set 7 | sukumo
# Processing Record 48 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 7 | jawhar
# Processing Record 50 of Set 7 | betki
# City not found. Skipping...
# Processing Record 1 of Set 8 | buchanan
# Processing Record 2 of Set 8 | ashta
# Processing Record 3 of Set 8 | nha trang
# Processing Record 4 of Set 8 | palmer
# Processing Record 5 of Set 8 | belyy yar
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | aleksandrovskoye
# Processing Record 8 of Set 8 | oskarshamn
# Processing Record 9 of Set 8 | pasighat
# Processing Record 10 of Set 8 | mnogovershinnyy
# Processing Record 11 of Set 8 | sheridan
# Processing Record 12 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 8 | champerico
# Processing Record 14 of Set 8 | katsuura
# Processing Record 15 of Set 8 | hit
# Processing Record 16 of Set 8 | kaitangata
# Processing Record 17 of Set 8 | new ulm
# Processing Record 18 of Set 8 | bilma
# Processing Record 19 of Set 8 | narsaq
# Processing Record 20 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 8 | maumere
# Processing Record 22 of Set 8 | port keats
# Processing Record 23 of Set 8 | surskoye
# Processing Record 24 of Set 8 | vanimo
# Processing Record 25 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 8 | jalingo
# Processing Record 27 of Set 8 | omboue
# Processing Record 28 of Set 8 | kamyshevatskaya
# Processing Record 29 of Set 8 | mancio lima
# Processing Record 30 of Set 8 | chipinge
# Processing Record 31 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 8 | ponta do sol
# Processing Record 33 of Set 8 | santander
# Processing Record 34 of Set 8 | santa rosalia
# Processing Record 35 of Set 8 | borovskoy
# Processing Record 36 of Set 8 | samarai
# Processing Record 37 of Set 8 | khakhea
# Processing Record 38 of Set 8 | ketchikan
# Processing Record 39 of Set 8 | shaowu
# Processing Record 40 of Set 8 | viedma
# Processing Record 41 of Set 8 | winston-salem
# Processing Record 42 of Set 8 | wajir
# Processing Record 43 of Set 8 | qarayeri
# Processing Record 44 of Set 8 | alofi
# Processing Record 45 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 8 | ambon
# Processing Record 47 of Set 8 | ascension
# Processing Record 48 of Set 8 | mehran
# Processing Record 49 of Set 8 | ngunguru
# Processing Record 50 of Set 8 | tupancireta
# Processing Record 1 of Set 9 | itaituba
# Processing Record 2 of Set 9 | egvekinot
# Processing Record 3 of Set 9 | urubicha
# Processing Record 4 of Set 9 | rumoi
# Processing Record 5 of Set 9 | sosua
# Processing Record 6 of Set 9 | sept-iles
# Processing Record 7 of Set 9 | porto nacional
# Processing Record 8 of Set 9 | kushiro
# Processing Record 9 of Set 9 | sawakin
# Processing Record 10 of Set 9 | la plaine
# Processing Record 11 of Set 9 | kabare
# Processing Record 12 of Set 9 | zaozerne
# Processing Record 13 of Set 9 | shahr-e babak
# Processing Record 14 of Set 9 | clyde river
# Processing Record 15 of Set 9 | tateyama
# Processing Record 16 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 9 | poum
# Processing Record 19 of Set 9 | vila franca do campo
# Processing Record 20 of Set 9 | sao filipe
# Processing Record 21 of Set 9 | ancud
# Processing Record 22 of Set 9 | kuito
# Processing Record 23 of Set 9 | srivardhan
# Processing Record 24 of Set 9 | mahon
# Processing Record 25 of Set 9 | balkhash
# Processing Record 26 of Set 9 | odoyev
# Processing Record 27 of Set 9 | nantucket
# Processing Record 28 of Set 9 | sola
# Processing Record 29 of Set 9 | copala
# Processing Record 30 of Set 9 | sayat
# Processing Record 31 of Set 9 | pemba
# Processing Record 32 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 9 | ayagoz
# Processing Record 34 of Set 9 | cintalapa
# Processing Record 35 of Set 9 | rondonopolis
# Processing Record 36 of Set 9 | bambanglipuro
# Processing Record 37 of Set 9 | cockburn town
# Processing Record 38 of Set 9 | hambantota
# Processing Record 39 of Set 9 | uzumlu
# City not found. Skipping...
# Processing Record 40 of Set 9 | yazykovo
# Processing Record 41 of Set 9 | ilhabela
# Processing Record 42 of Set 9 | kargasok
# Processing Record 43 of Set 9 | kruisfontein
# Processing Record 44 of Set 9 | luanda
# Processing Record 45 of Set 9 | bara
# Processing Record 46 of Set 9 | visby
# Processing Record 47 of Set 9 | poshekhonye
# Processing Record 48 of Set 9 | zaysan
# Processing Record 49 of Set 9 | matay
# Processing Record 50 of Set 9 | aleksandrov gay
# Processing Record 1 of Set 10 | murashi
# Processing Record 2 of Set 10 | daru
# Processing Record 3 of Set 10 | te anau
# Processing Record 4 of Set 10 | floro
# Processing Record 5 of Set 10 | ixtapa
# Processing Record 6 of Set 10 | fort-shevchenko
# Processing Record 7 of Set 10 | qingyuan
# Processing Record 8 of Set 10 | sidhi
# Processing Record 9 of Set 10 | marv dasht
# City not found. Skipping...
# Processing Record 10 of Set 10 | bima
# Processing Record 11 of Set 10 | komsomolskiy
# Processing Record 12 of Set 10 | buala
# Processing Record 13 of Set 10 | altamont
# Processing Record 14 of Set 10 | volary
# Processing Record 15 of Set 10 | bontang
# Processing Record 16 of Set 10 | killybegs
# Processing Record 17 of Set 10 | chunhuhub
# Processing Record 18 of Set 10 | saint anthony
# Processing Record 19 of Set 10 | dongying
# Processing Record 20 of Set 10 | port hawkesbury
# Processing Record 21 of Set 10 | adrar
# Processing Record 22 of Set 10 | kalvarija
# Processing Record 23 of Set 10 | mao
# Processing Record 24 of Set 10 | san lawrenz
# Processing Record 25 of Set 10 | dwarka
# Processing Record 26 of Set 10 | naze
# Processing Record 27 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 10 | amlimay
# Processing Record 29 of Set 10 | turka
# Processing Record 30 of Set 10 | shingu
# Processing Record 31 of Set 10 | shimoda
# Processing Record 32 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 10 | the valley
# Processing Record 34 of Set 10 | xining
# Processing Record 35 of Set 10 | lamu
# Processing Record 36 of Set 10 | mabini
# Processing Record 37 of Set 10 | mugur-aksy
# Processing Record 38 of Set 10 | clinton
# Processing Record 39 of Set 10 | antofagasta
# Processing Record 40 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 10 | joshimath
# Processing Record 42 of Set 10 | gornoye loo
# Processing Record 43 of Set 10 | souillac
# Processing Record 44 of Set 10 | winnemucca
# Processing Record 45 of Set 10 | honiara
# Processing Record 46 of Set 10 | hermagor
# Processing Record 47 of Set 10 | vermillion
# Processing Record 48 of Set 10 | flin flon
# Processing Record 49 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 50 of Set 10 | krasnokamensk
# Processing Record 1 of Set 11 | gouyave
# Processing Record 2 of Set 11 | havoysund
# Processing Record 3 of Set 11 | abu dhabi
# Processing Record 4 of Set 11 | obluche
# City not found. Skipping...
# Processing Record 5 of Set 11 | skibbereen
# Processing Record 6 of Set 11 | inhambane
# Processing Record 7 of Set 11 | upata
# Processing Record 8 of Set 11 | yuty
# Processing Record 9 of Set 11 | usinsk
# Processing Record 10 of Set 11 | kholodnyy
# Processing Record 11 of Set 11 | amatlan
# City not found. Skipping...
# Processing Record 12 of Set 11 | semey
# Processing Record 13 of Set 11 | lumeje
# Processing Record 14 of Set 11 | villa bruzual
# Processing Record 15 of Set 11 | axim
# Processing Record 16 of Set 11 | yerbogachen
# Processing Record 17 of Set 11 | huizhou
# Processing Record 18 of Set 11 | chkalovskoye
# Processing Record 19 of Set 11 | constitucion
# Processing Record 20 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 11 | sikonge
# Processing Record 22 of Set 11 | hay river
# Processing Record 23 of Set 11 | nioro
# Processing Record 24 of Set 11 | cartagena
# Processing Record 25 of Set 11 | west wendover
# Processing Record 26 of Set 11 | lincoln
# Processing Record 27 of Set 11 | charagua
# Processing Record 28 of Set 11 | seymchan
# Processing Record 29 of Set 11 | olavarria
# Processing Record 30 of Set 11 | maningrida
# Processing Record 31 of Set 11 | yerofey pavlovich
# Processing Record 32 of Set 11 | yar-sale
# Processing Record 33 of Set 11 | touros
# Processing Record 34 of Set 11 | siauliai
# Processing Record 35 of Set 11 | kempsey
# Processing Record 36 of Set 11 | fortuna foothills
# Processing Record 37 of Set 11 | la romana
# Processing Record 38 of Set 11 | tomatlan
# Processing Record 39 of Set 11 | valparaiso
# Processing Record 40 of Set 11 | rozkishne
# Processing Record 41 of Set 11 | cam ranh
# Processing Record 42 of Set 11 | wheeling
# Processing Record 43 of Set 11 | mount isa
# Processing Record 44 of Set 11 | luganville
# Processing Record 45 of Set 11 | kampot
# Processing Record 46 of Set 11 | acapulco
# Processing Record 47 of Set 11 | maridi
# Processing Record 48 of Set 11 | shu
# Processing Record 49 of Set 11 | coos bay
# Processing Record 50 of Set 11 | geraldton
# Processing Record 1 of Set 12 | porto walter
# Processing Record 2 of Set 12 | hofn
# Processing Record 3 of Set 12 | yartsevo
# Processing Record 4 of Set 12 | galveston
# Processing Record 5 of Set 12 | tondano
# Processing Record 6 of Set 12 | san policarpo
# Processing Record 7 of Set 12 | emerald
# Processing Record 8 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 9 of Set 12 | saint-pierre
# Processing Record 10 of Set 12 | houma
# Processing Record 11 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 12 of Set 12 | ambilobe
# Processing Record 13 of Set 12 | lampang
# Processing Record 14 of Set 12 | porto seguro
# Processing Record 15 of Set 12 | labuhan
# Processing Record 16 of Set 12 | tecate
# Processing Record 17 of Set 12 | nelson bay
# Processing Record 18 of Set 12 | lasa
# Processing Record 19 of Set 12 | lagoa
# Processing Record 20 of Set 12 | umm kaddadah
# Processing Record 21 of Set 12 | ust-maya
# Processing Record 22 of Set 12 | sarahan
# Processing Record 23 of Set 12 | puri
# Processing Record 24 of Set 12 | tabas
# Processing Record 25 of Set 12 | nalut
# Processing Record 26 of Set 12 | plouzane
# Processing Record 27 of Set 12 | leh
# Processing Record 28 of Set 12 | tromso
# Processing Record 29 of Set 12 | praia
# Processing Record 30 of Set 12 | capitan bado
# Processing Record 31 of Set 12 | warrington
# Processing Record 32 of Set 12 | itoman
# Processing Record 33 of Set 12 | fairlie
# Processing Record 34 of Set 12 | nuuk
# Processing Record 35 of Set 12 | gawler
# Processing Record 36 of Set 12 | teguldet
# Processing Record 37 of Set 12 | mehamn
# Processing Record 38 of Set 12 | ler
# Processing Record 39 of Set 12 | raga
# Processing Record 40 of Set 12 | otane
# Processing Record 41 of Set 12 | qaqortoq
# Processing Record 42 of Set 12 | bibiani
# Processing Record 43 of Set 12 | bhadasar
# Processing Record 44 of Set 12 | ternate
# Processing Record 45 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 12 | hovd
# Processing Record 47 of Set 12 | jadu
# Processing Record 48 of Set 12 | oksfjord
# Processing Record 49 of Set 12 | ugoofaaru
# Processing Record 50 of Set 12 | darhan
# Processing Record 1 of Set 13 | khem karan
# Processing Record 2 of Set 13 | margate
# Processing Record 3 of Set 13 | batemans bay
# Processing Record 4 of Set 13 | voyvozh
# Processing Record 5 of Set 13 | fonte boa
# Processing Record 6 of Set 13 | phan thiet
# Processing Record 7 of Set 13 | aswan
# Processing Record 8 of Set 13 | harper
# Processing Record 9 of Set 13 | berdigestyakh
# Processing Record 10 of Set 13 | ballstad
# City not found. Skipping...
# Processing Record 11 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 13 | iwaki
# Processing Record 13 of Set 13 | warrnambool
# Processing Record 14 of Set 13 | waipawa
# Processing Record 15 of Set 13 | isabela
# Processing Record 16 of Set 13 | oyama
# Processing Record 17 of Set 13 | pangnirtung
# Processing Record 18 of Set 13 | leningradskiy
# Processing Record 19 of Set 13 | suntar
# Processing Record 20 of Set 13 | savalou
# Processing Record 21 of Set 13 | wangqing
# Processing Record 22 of Set 13 | winona
# Processing Record 23 of Set 13 | birobidzhan
# Processing Record 24 of Set 13 | salento
# Processing Record 25 of Set 13 | miri
# Processing Record 26 of Set 13 | roanoke rapids
# Processing Record 27 of Set 13 | half moon bay
# Processing Record 28 of Set 13 | general pico
# Processing Record 29 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 13 | wundanyi
# Processing Record 31 of Set 13 | tlyarota
# City not found. Skipping...
# Processing Record 32 of Set 13 | burica
# City not found. Skipping...
# Processing Record 33 of Set 13 | avon
# Processing Record 34 of Set 13 | polyarnyy
# Processing Record 35 of Set 13 | esso
# Processing Record 36 of Set 13 | haines junction
# Processing Record 37 of Set 13 | port lincoln
# Processing Record 38 of Set 13 | quelimane
# Processing Record 39 of Set 13 | terra santa
# Processing Record 40 of Set 13 | urumqi
# Processing Record 41 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 42 of Set 13 | cap malheureux
# Processing Record 43 of Set 13 | bondoukou
# Processing Record 44 of Set 13 | ankang
# Processing Record 45 of Set 13 | rongcheng
# Processing Record 46 of Set 13 | mogadishu
# Processing Record 47 of Set 13 | taltal
# Processing Record 48 of Set 13 | porto santo
# Processing Record 49 of Set 13 | barguzin
# Processing Record 50 of Set 13 | san cristobal
# Processing Record 1 of Set 14 | torres
# Processing Record 2 of Set 14 | teluknaga
# Processing Record 3 of Set 14 | kamareddi
# Processing Record 4 of Set 14 | nanga eboko
# Processing Record 5 of Set 14 | ada
# Processing Record 6 of Set 14 | juneau
# Processing Record 7 of Set 14 | leshukonskoye
# Processing Record 8 of Set 14 | naica
# Processing Record 9 of Set 14 | cabinda
# Processing Record 10 of Set 14 | huanren
# Processing Record 11 of Set 14 | thaton
# Processing Record 12 of Set 14 | guozhen
# Processing Record 13 of Set 14 | abu kamal
# Processing Record 14 of Set 14 | acari
# Processing Record 15 of Set 14 | hammerfest
# Processing Record 16 of Set 14 | horta
# Processing Record 17 of Set 14 | estevan
# Processing Record 18 of Set 14 | gwanda
# Processing Record 19 of Set 14 | tankhoy
# Processing Record 20 of Set 14 | yuxia
# Processing Record 21 of Set 14 | brive-la-gaillarde
# Processing Record 22 of Set 14 | port macquarie
# Processing Record 23 of Set 14 | tornio
# Processing Record 24 of Set 14 | santa luzia
# Processing Record 25 of Set 14 | price
# Processing Record 26 of Set 14 | miandrivazo
# Processing Record 27 of Set 14 | kungurtug
# Processing Record 28 of Set 14 | barcelona
# Processing Record 29 of Set 14 | hamilton
# Processing Record 30 of Set 14 | madimba
# Processing Record 31 of Set 14 | iwanai
# Processing Record 32 of Set 14 | vetluga
# Processing Record 33 of Set 14 | dicabisagan
# Processing Record 34 of Set 14 | yenagoa
# Processing Record 35 of Set 14 | el wasta
# City not found. Skipping...
# Processing Record 36 of Set 14 | ossora
# Processing Record 37 of Set 14 | kavaratti
# Processing Record 38 of Set 14 | fort nelson
# Processing Record 39 of Set 14 | filadelfia
# Processing Record 40 of Set 14 | kolo
# Processing Record 41 of Set 14 | kapoeta
# Processing Record 42 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 43 of Set 14 | myitkyina
# Processing Record 44 of Set 14 | coihaique
# Processing Record 45 of Set 14 | hare bay
# Processing Record 46 of Set 14 | lata
# Processing Record 47 of Set 14 | tatawin
# Processing Record 48 of Set 14 | montepuez
# Processing Record 49 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 14 | betare oya
# Processing Record 1 of Set 15 | constantine
# Processing Record 2 of Set 15 | dzilam gonzalez
# Processing Record 3 of Set 15 | biltine
# Processing Record 4 of Set 15 | baykit
# Processing Record 5 of Set 15 | durango
# Processing Record 6 of Set 15 | ewa beach
# Processing Record 7 of Set 15 | san javier
# Processing Record 8 of Set 15 | inongo
# Processing Record 9 of Set 15 | lisakovsk
# Processing Record 10 of Set 15 | palu
# Processing Record 11 of Set 15 | suao
# City not found. Skipping...
# Processing Record 12 of Set 15 | hailar
# Processing Record 13 of Set 15 | yarkovo
# Processing Record 14 of Set 15 | fond du lac
# Processing Record 15 of Set 15 | griffith
# Processing Record 16 of Set 15 | artyom
# Processing Record 17 of Set 15 | aberdeen
# Processing Record 18 of Set 15 | inirida
# Processing Record 19 of Set 15 | saint-louis
# Processing Record 20 of Set 15 | foxton
# Processing Record 21 of Set 15 | lorengau
# Processing Record 22 of Set 15 | siniscola
# Processing Record 23 of Set 15 | obidos
# Processing Record 24 of Set 15 | council bluffs
# Processing Record 25 of Set 15 | oudtshoorn
# Processing Record 26 of Set 15 | vostok
# Processing Record 27 of Set 15 | karratha
# Processing Record 28 of Set 15 | bembereke
# Processing Record 29 of Set 15 | deputatskiy
# Processing Record 30 of Set 15 | along
# Processing Record 31 of Set 15 | sistranda
# Processing Record 32 of Set 15 | dawei
# Processing Record 33 of Set 15 | havre-saint-pierre
# Processing Record 34 of Set 15 | rumphi
# Processing Record 35 of Set 15 | mandurah
# Processing Record 36 of Set 15 | concarneau
# Processing Record 37 of Set 15 | magadi
# Processing Record 38 of Set 15 | kailua
# Processing Record 39 of Set 15 | varna
# Processing Record 40 of Set 15 | odweyne
# Processing Record 41 of Set 15 | amapa
# Processing Record 42 of Set 15 | corrente
# Processing Record 43 of Set 15 | kobryn
# Processing Record 44 of Set 15 | simojovel
# Processing Record 45 of Set 15 | cefalu
# Processing Record 46 of Set 15 | nyrob
# Processing Record 47 of Set 15 | khandyga
# Processing Record 48 of Set 15 | bousso
# Processing Record 49 of Set 15 | robertson
# Processing Record 50 of Set 15 | ndioum
# Processing Record 1 of Set 16 | manakara
# Processing Record 2 of Set 16 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 3 of Set 16 | akranes
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Jackson  42.4165 -122.8345     49.87        79          90
# 1  Campina Grande Do Sul -25.3056  -49.0553     86.90        49           1
# 2               Luderitz -26.6481   15.1594     63.91        78           0
# 3              Ilulissat  69.2167  -51.1000     26.62        46          75
# 4                 Albany  42.6001  -73.9662     23.52        77         100
# 5    Santa Maria Del Oro  25.9333 -105.3667     62.60        23           1
# 6             Lavrentiya  65.5833 -171.0000     -1.57        99          77
# 7                  Tiksi  71.6872  128.8694    -20.18        99         100
# 8                Ushuaia -54.8000  -68.3000     51.42        43          75
# 9                  Daboh  26.0025   78.8761     55.29        50           2
#
#    Wind Speed Country                 Date Current Description
# 0       18.41      US  2022-01-03 18:32:46          light rain
# 1        7.72      BR  2022-01-03 18:36:43           clear sky
# 2       18.10      NA  2022-01-03 18:36:44           clear sky
# 3       14.97      GL  2022-01-03 18:36:44       broken clouds
# 4        1.99      US  2022-01-03 18:36:44     overcast clouds
# 5        7.63      MX  2022-01-03 18:36:44           clear sky
# 6        3.85      RU  2022-01-03 18:26:55       broken clouds
# 7        4.76      RU  2022-01-03 18:36:45     overcast clouds
# 8       29.93      AR  2022-01-03 18:36:45       broken clouds
# 9        1.43      IN  2022-01-03 18:36:45           clear sky

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Jackson      US  42.4165 -122.8345     49.87        79
# 1    Campina Grande Do Sul      BR -25.3056  -49.0553     86.90        49
# 2                 Luderitz      NA -26.6481   15.1594     63.91        78
# 3                Ilulissat      GL  69.2167  -51.1000     26.62        46
# 4                   Albany      US  42.6001  -73.9662     23.52        77
# ..                     ...     ...      ...       ...       ...       ...
# 684                 Bousso      TD  10.4795   16.7117     74.23        21
# 685              Robertson      US  36.5167  -86.8667     35.04        76
# 686                 Ndioum      SN  16.5129  -14.6471     79.84        11
# 687               Manakara      MG -22.1333   48.0167     76.42        82
# 688                Akranes      IS  64.3218  -22.0749     23.56        84
#
#      Cloudiness  Wind Speed Current Description
# 0            90       18.41          light rain
# 1             1        7.72           clear sky
# 2             0       18.10           clear sky
# 3            75       14.97       broken clouds
# 4           100        1.99     overcast clouds
# ..          ...         ...                 ...
# 684           2        8.75           clear sky
# 685          90        0.00     overcast clouds
# 686          12        9.66          few clouds
# 687          45        2.59    scattered clouds
# 688          16       10.38          few clouds
#
# [689 rows x 9 columns]

# %%
output_data_file="WeatherPy_Database.csv"
#export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City ID")
